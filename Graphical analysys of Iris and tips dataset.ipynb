# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading dataset
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(15,8))
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='area',alpha=.8,stacked=False)
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
#comparison between two features

# %%
df.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# C:\Users\HP\Anaconda3\envs\Practice\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',s=200)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,cmap='viridis')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
## 3-d plotting

# %%
from mpl_toolkits import mplot3d

# %%
x=np.linspace(-1,7,30)
x
# Out:
# array([-1.        , -0.72413793, -0.44827586, -0.17241379,  0.10344828,
#         0.37931034,  0.65517241,  0.93103448,  1.20689655,  1.48275862,
#         1.75862069,  2.03448276,  2.31034483,  2.5862069 ,  2.86206897,
#         3.13793103,  3.4137931 ,  3.68965517,  3.96551724,  4.24137931,
#         4.51724138,  4.79310345,  5.06896552,  5.34482759,  5.62068966,
#         5.89655172,  6.17241379,  6.44827586,  6.72413793,  7.        ])

# %%
y=np.linspace(-1,6,30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z=x+y
x
# Out:
# array([-1.        , -0.72413793, -0.44827586, -0.17241379,  0.10344828,
#         0.37931034,  0.65517241,  0.93103448,  1.20689655,  1.48275862,
#         1.75862069,  2.03448276,  2.31034483,  2.5862069 ,  2.86206897,
#         3.13793103,  3.4137931 ,  3.68965517,  3.96551724,  4.24137931,
#         4.51724138,  4.79310345,  5.06896552,  5.34482759,  5.62068966,
#         5.89655172,  6.17241379,  6.44827586,  6.72413793,  7.        ])

# %%
ax=plt.axes(projection="3d")
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
z=(x**2)+(y**2)
z
# Out:
# array([2.00000000e+00, 1.09988109e+00, 4.68489893e-01, 1.05826397e-01,
#        1.18906064e-02, 1.86682521e-01, 6.30202140e-01, 1.34244946e+00,
#        2.32342449e+00, 3.57312723e+00, 5.09155767e+00, 6.87871581e+00,
#        8.93460166e+00, 1.12592152e+01, 1.38525565e+01, 1.67146254e+01,
#        1.98454221e+01, 2.32449465e+01, 2.69131986e+01, 3.08501784e+01,
#        3.50558859e+01, 3.95303210e+01, 4.42734839e+01, 4.92853746e+01,
#        5.45659929e+01, 6.01153389e+01, 6.59334126e+01, 7.20202140e+01,
#        7.83757432e+01, 8.50000000e+01])

# %%
ax=plt.axes(projection="3d")
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax=plt.axes(projection="3d")
ax.plot3D(df["sepal_length"],df['petal_length'],df["petal_width"])
ax.set_xlabel('sepal_length')
ax.set_ylabel('petal_length')
ax.set_zlabel('petal_width')
# Out:
# Text(0.5, 0, 'petal_width')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## bar graph plot
# #row wise comparison done by bar graph

# %%
df.iloc[5:10].plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.iloc[5:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.iloc[5:10].plot(kind="barh",figsize=(20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# #histogram used for group by count answer (range,frequency)

# %%
df.plot(kind="hist",figsize=(20,7))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',figsize=(15,8))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.hist(figsize=(20,10),color='r',alpha=0.9)
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="c59de8a4-3970-4f72-becf-262356ec03e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
pip install chart_studio
# Out:
# ...
#      -------------------------------------- 64.4/64.4 kB 433.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.iplot(x='sepal_length',y='petal_length',kind='scatter',mode='markers')
# Out:
# <div>                            <div id="fbc5e483-73ff-4d75-9ff7-66b5e48ab37c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iloc[5:10].iplot(kind='bar')
# Out:
# <div>                            <div id="539b7cf1-9663-4a76-9a10-e51a77367a60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['sepal_length'].iloc[5:10].iplot(kind='bar')
# Out:
# <div>                            <div id="5a9fb38d-5068-43e1-9ec8-9aa65662ed17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['sepal_length'].iloc[5:10].iplot(kind='bar')
# Out:
# <div>                            <div id="8bb801af-ef7f-44ff-9769-2e92cf3c9a46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',kind='bubble',size='sepal_length')
# Out:
# <div>                            <div id="8da5be7f-6eb0-441e-b826-5399596ab731" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',z='sepal_width',kind='bubble3d',size='sepal_length')
# Out:
# <div>                            <div id="06d7735f-683c-4e31-94cb-19b06ee4abd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1=sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(kind="scatter",x='total_bill',y='tip')
# Out:
# C:\Users\HP\Anaconda3\envs\Practice\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(kind="scatter",x='total_bill',y='tip',mode='markers')
# Out:
# <div>                            <div id="0f594275-e186-41ca-994c-7c1c66f9189b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(kind="scatter",x='total_bill',y='tip',data=df1,hue='smoker')

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(kind="scatter",x='total_bill',y='tip',data=df1,hue='time',style='sex')

# %%
#hue  and style use for grouping

# %%
sns.relplot(kind="scatter",x='total_bill',y='tip',data=df1,col='time')

# %%
sns.relplot(kind="scatter",x='total_bill',y='tip',data=df1,col='sex')

# %%
sns.relplot(x='sepal_length',y='petal_length',data=df,col='species')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#which day customer is coming more

# %%
sns.relplot(kind="scatter",x='total_bill',y='tip',data=df1,col='day')

# %%
#categorical plot

# %%
sns.catplot(x='day',y='total_bill',data=df1)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="adc44ef3-f907-453d-a5dd-d3f7cd174b7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ##plot based on seaborn

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x=df1.total_bill, y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill, y=df1.tip,kind='hex')

# %%
sns.pairplot(df1)

# %%
sns.regplot(x=df1.total_bill,y=df1.tip)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
#plotly express and cufflinks use mainly

# %%
#matplotlib,seaborn
